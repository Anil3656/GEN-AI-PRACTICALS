# %% [markdown]
# Builded A Text based RAG Model Without using LLM

# %%
# !pip install -U \
    chromadb==0.5.15 \
    langchain==0.2.11 \
    langchain-community==0.2.10 \
    langchain-chroma==0.1.4 \
    langchain-text-splitters==0.2.2 \
    langchain-groq==0.1.6 \
    transformers==4.38.2 \
    sentence-transformers==3.0.1 \
    unstructured==0.16.5 \
    unstructured[pdf]==0.16.5 \
    peft==0.7.1
# Out:
# Requirement already satisfied: chromadb==0.5.15 in /usr/local/lib/python3.12/dist-packages (0.5.15)
# Requirement already satisfied: langchain==0.2.11 in /usr/local/lib/python3.12/dist-packages (0.2.11)
# Requirement already satisfied: langchain-community==0.2.10 in /usr/local/lib/python3.12/dist-packages (0.2.10)
# Requirement already satisfied: langchain-chroma==0.1.4 in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: langchain-text-splitters==0.2.2 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: langchain-groq==0.1.6 in /usr/local/lib/python3.12/dist-packages (0.1.6)
# Requirement already satisfied: transformers==4.38.2 in /usr/local/lib/python3.12/dist-packages (4.38.2)
# Requirement already satisfied: sentence-transformers==3.0.1 in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: unstructured==0.16.5 in /usr/local/lib/python3.12/dist-packages (0.16.5)
# Requirement already satisfied: peft==0.7.1 in /usr/local/lib/python3.12/dist-packages (0.7.1)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (2.12.3)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.118.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.5.15) (13.9.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.2.11) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain==0.2.11) (3.13.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in /usr/local/lib/python3.12/dist-packages (from langchain==0.2.11) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain==0.2.11) (0.1.147)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain==0.2.11) (2.32.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community==0.2.10) (0.6.7)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from langchain-groq==0.1.6) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.38.2) (0.7.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.0.1) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.0.1) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.0.1) (1.16.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==3.0.1) (11.3.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (6.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (4.13.5)
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (2.15.0)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (2025.11.16)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (3.14.3)
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (2.2.1)
# Requirement already satisfied: unstructured-client in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (0.42.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (1.17.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (5.9.5)
# Requirement already satisfied: python-oxmsg in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (0.0.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from unstructured==0.16.5) (1.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.7.1) (1.12.0)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (1.20.0)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (1.17.0)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (20251107)
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (10.0.2)
# Requirement already satisfied: pi-heif in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (1.1.1)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (6.4.1)
# Requirement already satisfied: google-cloud-vision in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (3.11.0)
# Requirement already satisfied: effdet in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (0.4.1)
# Requirement already satisfied: unstructured-inference==0.8.1 in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (0.8.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.12/dist-packages (from unstructured[pdf]==0.16.5) (0.3.15)
# Requirement already satisfied: layoutparser in /usr/local/lib/python3.12/dist-packages (from unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (0.0.20)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.12/dist-packages (from unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (3.10.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (1.0.22)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.22.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb==0.5.15) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (0.9.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.95.2->chromadb==0.5.15) (0.48.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.1.6) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb==0.5.15) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb==0.5.15) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb==0.5.15) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.15) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (1.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.15) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.15) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.15) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.15) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.15) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.15) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.15) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.15) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.15) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.15) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.15) (0.60b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.15) (0.60b1)
# Requirement already satisfied: opentelemetry-util-http==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.15) (0.60b1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-asgi==0.60b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.15) (3.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.9->chromadb==0.5.15) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.9->chromadb==0.5.15) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.9->chromadb==0.5.15) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.2.11) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb==0.5.15) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb==0.5.15) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.11) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (75.2.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.5.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==0.5.15) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==0.5.15) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.15) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->unstructured==0.16.5) (2.8)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]==0.16.5) (0.24.0+cu126)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]==0.16.5) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]==0.16.5) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.16.5) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-vision->unstructured[pdf]==0.16.5) (1.26.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured==0.16.5) (0.5.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured==0.16.5) (1.5.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->unstructured[pdf]==0.16.5) (0.5.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six->unstructured[pdf]==0.16.5) (43.0.3)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.12/dist-packages (from pikepdf->unstructured[pdf]==0.16.5) (1.3.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.12/dist-packages (from python-oxmsg->unstructured==0.16.5) (0.47)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers==3.0.1) (3.6.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured==0.16.5) (24.1.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.16.5) (2.0.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.16.5) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.15) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.15) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.15) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.15) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.5.15) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0->effdet->unstructured[pdf]==0.16.5) (4.9.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.15) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.15) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1) (3.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (2.2.2)
# Requirement already satisfied: iopath in /usr/local/lib/python3.12/dist-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.12/dist-packages (from layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (0.11.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (3.2.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==0.5.15) (3.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.16.5) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.15) (0.6.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (2025.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber->layoutparser->unstructured-inference==0.8.1->unstructured[pdf]==0.16.5) (5.2.0)

# %% [markdown]
# Given an access using groq Api

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
  os.environ["GROQ_API_KEY"] = getpass.getpass("GROQ API Key:")
# Out:
# GROQ API Key:··········

# %%
# Document Loader

from langchain.document_loaders import TextLoader
loader = TextLoader('/content/drive/MyDrive/Colab Notebooks/Colab Notebooks/india.txt')
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/Colab Notebooks/Colab Notebooks/india.txt'}, page_content='(Cricket, Politics, Actors, Environment, Nature)\n\nCricket is one of the most popular sports in the world.\n\nIt is played between two teams of eleven players each.\n\nThe game includes batting, bowling, and fielding skills.\n\nTest, ODI, and T20 are the three main formats.\n\nT20 cricket is the fastest and most exciting format.\n\nA batsman scores runs by hitting the ball.\n\nBowlers try to take wickets to stop the runs.\n\nFielders support the team with catches and run-outs.\n\nStrategy and teamwork play a big role in winning.\n\nCricket creates passion, excitement, and unity among fans.\n\n🏛️\n\nPolitics is the system used to govern a country or region.\n\nLeaders and representatives make decisions for the people.\n\nPolitical parties reflect different ideologies and ideas.\n\nElections allow citizens to choose their leaders.\n\nGood governance focuses on development and welfare.\n\nPolicies shape education, health, economy, and society.\n\nDemocracy gives people the right to vote and express views.\n\nPolitical debates help understand different perspectives.\n\nResponsible leadership brings stability and progress.\n\nPolitics affects every aspect of daily life.\n\n🎬\n\nActors bring stories to life through their performances.\n\nThey work in movies, TV shows, theatre, and digital platforms.\n\nGood acting requires emotion, expression, and timing.\n\nSome actors become global icons due to their talent.\n\nThey use body language and voice to create impact.\n\nMany actors inspire millions with their roles.\n\nBehind the scenes, they work long hours and face challenges.\n\nAwards and recognition encourage their hard work.\n\nActors help audiences connect to characters and emotions.\n\n🌍\n\nThe environment includes air, water, land, and living organisms.\n\nA healthy environment is essential for human survival.\n\n\nPollution is harming our natural resources.\n\nClimate change is causing global temperature rise.\n\nDeforestation reduces biodiversity and affects rainfall.\n\nRecycling and waste management protect the environment.\n\nRenewable energy reduces dependency on fossil fuels.\n\nSaving water and electricity conserves natural resources.\n\nGovernments and individuals must work together.\n\nProtecting the environment ensures a safe future.\n\n🍃\n\nNature includes forests, rivers, mountains, and wildlife.\n\nIt provides beauty, peace, and inspiration.\n\nlants and animals maintain the balance of life.\n\nThe sound of rain, wind, and birds calms the mind.\n\nNature gives us fresh air and clean water.\n\nSeasons change the landscapes with unique charm.\n\nHumans depend on nature for food and shelter.\n\nPreserving nature is our responsibility.\n\nNatual places refresh the body and soul.\n\nNatre is the greatest gift to humanity.')]

# %%
print(documents)
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/Colab Notebooks/Colab Notebooks/india.txt'}, page_content='(Cricket, Politics, Actors, Environment, Nature)\n\nCricket is one of the most popular sports in the world.\n\nIt is played between two teams of eleven players each.\n\nThe game includes batting, bowling, and fielding skills.\n\nTest, ODI, and T20 are the three main formats.\n\nT20 cricket is the fastest and most exciting format.\n\nA batsman scores runs by hitting the ball.\n\nBowlers try to take wickets to stop the runs.\n\nFielders support the team with catches and run-outs.\n\nStrategy and teamwork play a big role in winning.\n\nCricket creates passion, excitement, and unity among fans.\n\n🏛️\n\nPolitics is the system used to govern a country or region.\n\nLeaders and representatives make decisions for the people.\n\nPolitical parties reflect different ideologies and ideas.\n\nElections allow citizens to choose their leaders.\n\nGood governance focuses on development and welfare.\n\nPolicies shape education, health, economy, and society.\n\nDemocracy gives people the right to vote and express views.\n\nPolitical debates help understand different perspectives.\n\nResponsible leadership brings stability and progress.\n\nPolitics affects every aspect of daily life.\n\n🎬\n\nActors bring stories to life through their performances.\n\nThey work in movies, TV shows, theatre, and digital platforms.\n\nGood acting requires emotion, expression, and timing.\n\nSome actors become global icons due to their talent.\n\nThey use body language and voice to create impact.\n\nMany actors inspire millions with their roles.\n\nBehind the scenes, they work long hours and face challenges.\n\nAwards and recognition encourage their hard work.\n\nActors help audiences connect to characters and emotions.\n\n🌍\n\nThe environment includes air, water, land, and living organisms.\n\nA healthy environment is essential for human survival.\n\n\nPollution is harming our natural resources.\n\nClimate change is causing global temperature rise.\n\nDeforestation reduces biodiversity and affects rainfall.\n\nRecycling and waste management protect the environment.\n\nRenewable energy reduces dependency on fossil fuels.\n\nSaving water and electricity conserves natural resources.\n\nGovernments and individuals must work together.\n\nProtecting the environment ensures a safe future.\n\n🍃\n\nNature includes forests, rivers, mountains, and wildlife.\n\nIt provides beauty, peace, and inspiration.\n\nlants and animals maintain the balance of life.\n\nThe sound of rain, wind, and birds calms the mind.\n\nNature gives us fresh air and clean water.\n\nSeasons change the landscapes with unique charm.\n\nHumans depend on nature for food and shelter.\n\nPreserving nature is our responsibility.\n\nNatual places refresh the body and soul.\n\nNatre is the greatest gift to humanity.')]

# %%
import textwrap

def wrap_text_preserve_newlines(text, width=110):
  #Splite the input text into lines based on newline characters
  lines = text.split('\n')

  #Wrap each line individually
  wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

  #Join the wrapper
  wrapped_text = '\n'.join(wrapped_lines)

  return wrapped_text

# %%
print(wrap_text_preserve_newlines(str(documents[0])))
# Out:
# page_content='(Cricket, Politics, Actors, Environment, Nature)
#
# Cricket is one of the most popular sports in the world.
#
# It is played between two teams of eleven players each.
#
# The game includes batting, bowling, and fielding skills.
#
# Test, ODI, and T20 are the three main formats.
#
# T20 cricket is the fastest and most exciting format.
#
# A batsman scores runs by hitting the ball.
#
# Bowlers try to take wickets to stop the runs.
#
# Fielders support the team with catches and run-outs.
#
# Strategy and teamwork play a big role in winning.
#
# Cricket creates passion, excitement, and unity among fans.
#
# 🏛️
#
# Politics is the system used to govern a country or region.
#
# Leaders and representatives make decisions for the people.
#
# Political parties reflect different ideologies and ideas.
#
# Elections allow citizens to choose their leaders.
#
# Good governance focuses on development and welfare.
#
# Policies shape education, health, economy, and society.
#
# Democracy gives people the right to vote and express views.
#
# Political debates help understand different perspectives.
#
# Responsible leadership brings stability and progress.
#
# Politics affects every aspect of daily life.
#
# 🎬
#
# Actors bring stories to life through their performances.
#
# They work in movies, TV shows, theatre, and digital platforms.
#
# Good acting requires emotion, expression, and timing.
#
# Some actors become global icons due to their talent.
#
# They use body language and voice to create impact.
#
# Many actors inspire millions with their roles.
#
# Behind the scenes, they work long hours and face challenges.
#
# Awards and recognition encourage their hard work.
#
# Actors help audiences connect to characters and emotions.
#
# 🌍
#
# The environment includes air, water, land, and living organisms.
#
# A healthy environment is essential for human survival.
#
#
# Pollution is harming our natural resources.
#
# Climate change is causing global temperature rise.
#
# Deforestation reduces biodiversity and affects rainfall.
#
# Recycling and waste management protect the environment.
#
# Renewable energy reduces dependency on fossil fuels.
#
# Saving water and electricity conserves natural resources.
#
# Governments and individuals must work together.
#
# Protecting the environment ensures a safe future.
#
# 🍃
#
# Nature includes forests, rivers, mountains, and wildlife.
#
# It provides beauty, peace, and inspiration.
#
# lants and animals maintain the balance of life.
#
# The sound of rain, wind, and birds calms the mind.
#
# Nature gives us fresh air and clean water.
#
# Seasons change the landscapes with unique charm.
#
# Humans depend on nature for food and shelter.
#
# Preserving nature is our responsibility.
#
# Natual places refresh the body and soul.
#
# Natre is the greatest gift to humanity.' metadata={'source': '/content/drive/MyDrive/Colab Notebooks/Colab
# Notebooks/india.txt'}

# %%
#Text Splitters

from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
len(docs)
# Out:
# 3

# %%
#!pip install -U langchain-huggingface sentence-transformers

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()

#embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#!pip install faiss-gpu
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (24.2)

# %%
from langchain.vectorstores import FAISS
db = FAISS.from_documents(docs, embeddings)

# %%
query = "explain about Politics"
docs = db.similarity_search(query)

# %%
print(wrap_text_preserve_newlines(str(docs[0].page_content)))
# Out:
# (Cricket, Politics, Actors, Environment, Nature)
#
# Cricket is one of the most popular sports in the world.
#
# It is played between two teams of eleven players each.
#
# The game includes batting, bowling, and fielding skills.
#
# Test, ODI, and T20 are the three main formats.
#
# T20 cricket is the fastest and most exciting format.
#
# A batsman scores runs by hitting the ball.
#
# Bowlers try to take wickets to stop the runs.
#
# Fielders support the team with catches and run-outs.
#
# Strategy and teamwork play a big role in winning.
#
# Cricket creates passion, excitement, and unity among fans.
#
# 🏛️
#
# Politics is the system used to govern a country or region.
#
# Leaders and representatives make decisions for the people.
#
# Political parties reflect different ideologies and ideas.
#
# Elections allow citizens to choose their leaders.
#
# Good governance focuses on development and welfare.
#
# Policies shape education, health, economy, and society.
#
# Democracy gives people the right to vote and express views.
